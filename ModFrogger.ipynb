# %%
import multiprocessing
multiprocessing.set_start_method('spawn', force=True)

from envs.FroggerEnv import CustomVecEnv

from agents.FroggerDQNAgent import DQNAgent

# %%
def make_env():
    return CustomVecEnv()

env = make_env()
# Out:
# Main process starting worker 0
# Main process starting worker 1
# Main process starting worker 2
# Main process starting worker 3

# %%
agent = DQNAgent(resume=False, env=env)
# Out:
# C:\Users\igarcialopez\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
agent.train()
# Out:
# Main process sending reset command...
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Episode 1 - Avg Reward: 0.00 - Epsilon: 0.9950 - Steps 0 - infos : ({'lives': 4, 'episode_frame_number': 460, 'frame_number': 460}, {'lives': 4, 'episode_frame_number': 520, 'frame_number': 520}, {'lives': 4, 'episode_frame_number': 472, 'frame_number': 472}, {'lives': 4, 'episode_frame_number': 432, 'frame_number': 432})
# Episode 1 - Avg Reward: 0.00 - Epsilon: 0.9900 - Steps 0 - infos : ({'lives': 4, 'episode_frame_number': 464, 'frame_number': 464}, {'lives': 4, 'episode_frame_number': 524, 'frame_number': 524}, {'lives': 4, 'episode_frame_number': 476, 'frame_number': 476}, {'lives': 4, 'episode_frame_number': 436, 'frame_number': 436})
# Episode 1 - Avg Reward: 0.00 - Epsilon: 0.9851 - Steps 0 - infos : ({'lives': 4, 'episode_frame_number': 468, 'frame_number': 468}, {'lives': 4, 'episode_frame_number': 528, 'frame_number': 528}, {'lives': 4, 'episode_frame_number': 480, 'frame_number': 480}, {'lives': 4, 'episode_frame_number': 440, 'frame_number': 440})
# Episode 1 - Avg Reward: 0.50 - Epsilon: 0.9801 - Steps 0 - infos : ({'lives': 4, 'episode_frame_number': 472, 'frame_number': 472}, {'lives': 4, 'episode_frame_number': 532, 'frame_number': 532}, {'lives': 3, 'episode_frame_number': 484, 'frame_number': 484}, {'lives': 4, 'episode_frame_number': 444, 'frame_number': 444})
# Episode 1 - Avg Reward: 0.50 - Epsilon: 0.9752 - Steps 0 - infos : ({'lives': 3, 'episode_frame_number': 476, 'frame_number': 476}, {'lives': 4, 'episode_frame_number': 536, 'frame_number': 536}, {'lives': 3, 'episode_frame_number': 488, 'frame_number': 488}, {'lives': 4, 'episode_frame_number': 448, 'frame_number': 448})
# Episode 1 - Avg Reward: 0.50 - Epsilon: 0.9704 - Steps 0 - infos : ({'lives': 3, 'episode_frame_number': 480, 'frame_number': 480}, {'lives': 4, 'episode_frame_number': 540, 'frame_number': 540}, {'lives': 3, 'episode_frame_number': 492, 'frame_number': 492}, {'lives': 4, 'episode_frame_number': 452, 'frame_number': 452})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9655 - Steps 0 - infos : ({'lives': 3, 'episode_frame_number': 484, 'frame_number': 484}, {'lives': 4, 'episode_frame_number': 544, 'frame_number': 544}, {'lives': 3, 'episode_frame_number': 496, 'frame_number': 496}, {'lives': 4, 'episode_frame_number': 456, 'frame_number': 456})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9607 - Steps 1 - infos : ({'lives': 3, 'episode_frame_number': 488, 'frame_number': 488}, {'lives': 4, 'episode_frame_number': 548, 'frame_number': 548}, {'lives': 3, 'episode_frame_number': 500, 'frame_number': 500}, {'lives': 4, 'episode_frame_number': 460, 'frame_number': 460})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9559 - Steps 2 - infos : ({'lives': 3, 'episode_frame_number': 492, 'frame_number': 492}, {'lives': 4, 'episode_frame_number': 552, 'frame_number': 552}, {'lives': 3, 'episode_frame_number': 504, 'frame_number': 504}, {'lives': 4, 'episode_frame_number': 464, 'frame_number': 464})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9511 - Steps 3 - infos : ({'lives': 3, 'episode_frame_number': 496, 'frame_number': 496}, {'lives': 4, 'episode_frame_number': 556, 'frame_number': 556}, {'lives': 3, 'episode_frame_number': 508, 'frame_number': 508}, {'lives': 4, 'episode_frame_number': 468, 'frame_number': 468})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9464 - Steps 4 - infos : ({'lives': 3, 'episode_frame_number': 500, 'frame_number': 500}, {'lives': 3, 'episode_frame_number': 560, 'frame_number': 560}, {'lives': 3, 'episode_frame_number': 512, 'frame_number': 512}, {'lives': 4, 'episode_frame_number': 472, 'frame_number': 472})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9416 - Steps 5 - infos : ({'lives': 3, 'episode_frame_number': 504, 'frame_number': 504}, {'lives': 3, 'episode_frame_number': 564, 'frame_number': 564}, {'lives': 3, 'episode_frame_number': 516, 'frame_number': 516}, {'lives': 4, 'episode_frame_number': 476, 'frame_number': 476})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9369 - Steps 6 - infos : ({'lives': 3, 'episode_frame_number': 508, 'frame_number': 508}, {'lives': 3, 'episode_frame_number': 568, 'frame_number': 568}, {'lives': 3, 'episode_frame_number': 520, 'frame_number': 520}, {'lives': 4, 'episode_frame_number': 480, 'frame_number': 480})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9322 - Steps 7 - infos : ({'lives': 3, 'episode_frame_number': 512, 'frame_number': 512}, {'lives': 3, 'episode_frame_number': 572, 'frame_number': 572}, {'lives': 3, 'episode_frame_number': 524, 'frame_number': 524}, {'lives': 3, 'episode_frame_number': 484, 'frame_number': 484})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9276 - Steps 8 - infos : ({'lives': 3, 'episode_frame_number': 516, 'frame_number': 516}, {'lives': 3, 'episode_frame_number': 576, 'frame_number': 576}, {'lives': 3, 'episode_frame_number': 528, 'frame_number': 528}, {'lives': 3, 'episode_frame_number': 488, 'frame_number': 488})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9229 - Steps 9 - infos : ({'lives': 3, 'episode_frame_number': 520, 'frame_number': 520}, {'lives': 3, 'episode_frame_number': 580, 'frame_number': 580}, {'lives': 3, 'episode_frame_number': 532, 'frame_number': 532}, {'lives': 3, 'episode_frame_number': 492, 'frame_number': 492})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9183 - Steps 10 - infos : ({'lives': 3, 'episode_frame_number': 524, 'frame_number': 524}, {'lives': 3, 'episode_frame_number': 584, 'frame_number': 584}, {'lives': 3, 'episode_frame_number': 536, 'frame_number': 536}, {'lives': 3, 'episode_frame_number': 496, 'frame_number': 496})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9137 - Steps 11 - infos : ({'lives': 3, 'episode_frame_number': 528, 'frame_number': 528}, {'lives': 3, 'episode_frame_number': 588, 'frame_number': 588}, {'lives': 3, 'episode_frame_number': 540, 'frame_number': 540}, {'lives': 3, 'episode_frame_number': 500, 'frame_number': 500})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9092 - Steps 12 - infos : ({'lives': 3, 'episode_frame_number': 532, 'frame_number': 532}, {'lives': 3, 'episode_frame_number': 592, 'frame_number': 592}, {'lives': 3, 'episode_frame_number': 544, 'frame_number': 544}, {'lives': 3, 'episode_frame_number': 504, 'frame_number': 504})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9046 - Steps 13 - infos : ({'lives': 3, 'episode_frame_number': 536, 'frame_number': 536}, {'lives': 3, 'episode_frame_number': 596, 'frame_number': 596}, {'lives': 3, 'episode_frame_number': 548, 'frame_number': 548}, {'lives': 3, 'episode_frame_number': 508, 'frame_number': 508})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.9001 - Steps 14 - infos : ({'lives': 3, 'episode_frame_number': 540, 'frame_number': 540}, {'lives': 3, 'episode_frame_number': 600, 'frame_number': 600}, {'lives': 3, 'episode_frame_number': 552, 'frame_number': 552}, {'lives': 3, 'episode_frame_number': 512, 'frame_number': 512})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.8956 - Steps 15 - infos : ({'lives': 3, 'episode_frame_number': 544, 'frame_number': 544}, {'lives': 3, 'episode_frame_number': 604, 'frame_number': 604}, {'lives': 3, 'episode_frame_number': 556, 'frame_number': 556}, {'lives': 3, 'episode_frame_number': 516, 'frame_number': 516})
# Episode 1 - Avg Reward: 0.75 - Epsilon: 0.8911 - Steps 16 - infos : ({'lives': 3, 'episode_frame_number': 548, 'frame_number': 548}, {'lives': 3, 'episode_frame_number': 608, 'frame_number': 608}, {'lives': 3, 'episode_frame_number': 560, 'frame_number': 560}, {'lives': 3, 'episode_frame_number': 520, 'frame_number': 520})
# Episode 1 - Avg Reward: 1.00 - Epsilon: 0.8867 - Steps 17 - infos : ({'lives': 3, 'episode_frame_number': 552, 'frame_number': 552}, {'lives': 3, 'episode_frame_number': 612, 'frame_number': 612}, {'lives': 2, 'episode_frame_number': 564, 'frame_number': 564}, {'lives': 3, 'episode_frame_number': 524, 'frame_number': 524})
# Episode 1 - Avg Reward: 1.00 - Epsilon: 0.8822 - Steps 18 - infos : ({'lives': 3, 'episode_frame_number': 556, 'frame_number': 556}, {'lives': 3, 'episode_frame_number': 616, 'frame_number': 616}, {'lives': 2, 'episode_frame_number': 568, 'frame_number': 568}, {'lives': 3, 'episode_frame_number': 528, 'frame_number': 528})
# Episode 1 - Avg Reward: 1.00 - Epsilon: 0.8778 - Steps 19 - infos : ({'lives': 3, 'episode_frame_number': 560, 'frame_number': 560}, {'lives': 3, 'episode_frame_number': 620, 'frame_number': 620}, {'lives': 2, 'episode_frame_number': 572, 'frame_number': 572}, {'lives': 3, 'episode_frame_number': 532, 'frame_number': 532})
# Episode 1 - Avg Reward: 1.00 - Epsilon: 0.8734 - Steps 20 - infos : ({'lives': 3, 'episode_frame_number': 564, 'frame_number': 564}, {'lives': 3, 'episode_frame_number': 624, 'frame_number': 624}, {'lives': 2, 'episode_frame_number': 576, 'frame_number': 576}, {'lives': 3, 'episode_frame_number': 536, 'frame_number': 536})
# Episode 1 - Avg Reward: 1.00 - Epsilon: 0.8691 - Steps 21 - infos : ({'lives': 3, 'episode_frame_number': 568, 'frame_number': 568}, {'lives': 3, 'episode_frame_number': 628, 'frame_number': 628}, {'lives': 2, 'episode_frame_number': 580, 'frame_number': 580}, {'lives': 3, 'episode_frame_number': 540, 'frame_number': 540})
# Episode 1 - Avg Reward: 1.00 - Epsilon: 0.8647 - Steps 22 - infos : ({'lives': 3, 'episode_frame_number': 572, 'frame_number': 572}, {'lives': 3, 'episode_frame_number': 632, 'frame_number': 632}, {'lives': 2, 'episode_frame_number': 584, 'frame_number': 584}, {'lives': 3, 'episode_frame_number': 544, 'frame_number': 544})
# Episode 1 - Avg Reward: 1.25 - Epsilon: 0.8604 - Steps 23 - infos : ({'lives': 3, 'episode_frame_number': 576, 'frame_number': 576}, {'lives': 3, 'episode_frame_number': 636, 'frame_number': 636}, {'lives': 2, 'episode_frame_number': 588, 'frame_number': 588}, {'lives': 3, 'episode_frame_number': 548, 'frame_number': 548})
# Episode 1 - Avg Reward: 1.25 - Epsilon: 0.8561 - Steps 24 - infos : ({'lives': 3, 'episode_frame_number': 580, 'frame_number': 580}, {'lives': 3, 'episode_frame_number': 640, 'frame_number': 640}, {'lives': 2, 'episode_frame_number': 592, 'frame_number': 592}, {'lives': 3, 'episode_frame_number': 552, 'frame_number': 552})
# Episode 1 - Avg Reward: 1.50 - Epsilon: 0.8518 - Steps 25 - infos : ({'lives': 3, 'episode_frame_number': 584, 'frame_number': 584}, {'lives': 3, 'episode_frame_number': 644, 'frame_number': 644}, {'lives': 2, 'episode_frame_number': 596, 'frame_number': 596}, {'lives': 3, 'episode_frame_number': 556, 'frame_number': 556})
# Episode 1 - Avg Reward: 1.50 - Epsilon: 0.8475 - Steps 26 - infos : ({'lives': 3, 'episode_frame_number': 588, 'frame_number': 588}, {'lives': 3, 'episode_frame_number': 648, 'frame_number': 648}, {'lives': 2, 'episode_frame_number': 600, 'frame_number': 600}, {'lives': 3, 'episode_frame_number': 560, 'frame_number': 560})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8433 - Steps 27 - infos : ({'lives': 2, 'episode_frame_number': 592, 'frame_number': 592}, {'lives': 3, 'episode_frame_number': 652, 'frame_number': 652}, {'lives': 2, 'episode_frame_number': 604, 'frame_number': 604}, {'lives': 3, 'episode_frame_number': 564, 'frame_number': 564})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8391 - Steps 28 - infos : ({'lives': 2, 'episode_frame_number': 596, 'frame_number': 596}, {'lives': 2, 'episode_frame_number': 656, 'frame_number': 656}, {'lives': 2, 'episode_frame_number': 608, 'frame_number': 608}, {'lives': 3, 'episode_frame_number': 568, 'frame_number': 568})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8349 - Steps 29 - infos : ({'lives': 2, 'episode_frame_number': 600, 'frame_number': 600}, {'lives': 2, 'episode_frame_number': 660, 'frame_number': 660}, {'lives': 2, 'episode_frame_number': 612, 'frame_number': 612}, {'lives': 3, 'episode_frame_number': 572, 'frame_number': 572})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8307 - Steps 30 - infos : ({'lives': 2, 'episode_frame_number': 604, 'frame_number': 604}, {'lives': 2, 'episode_frame_number': 664, 'frame_number': 664}, {'lives': 2, 'episode_frame_number': 616, 'frame_number': 616}, {'lives': 3, 'episode_frame_number': 576, 'frame_number': 576})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8266 - Steps 31 - infos : ({'lives': 2, 'episode_frame_number': 608, 'frame_number': 608}, {'lives': 2, 'episode_frame_number': 668, 'frame_number': 668}, {'lives': 2, 'episode_frame_number': 620, 'frame_number': 620}, {'lives': 3, 'episode_frame_number': 580, 'frame_number': 580})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8224 - Steps 32 - infos : ({'lives': 2, 'episode_frame_number': 612, 'frame_number': 612}, {'lives': 2, 'episode_frame_number': 672, 'frame_number': 672}, {'lives': 2, 'episode_frame_number': 624, 'frame_number': 624}, {'lives': 3, 'episode_frame_number': 584, 'frame_number': 584})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8183 - Steps 33 - infos : ({'lives': 2, 'episode_frame_number': 616, 'frame_number': 616}, {'lives': 2, 'episode_frame_number': 676, 'frame_number': 676}, {'lives': 2, 'episode_frame_number': 628, 'frame_number': 628}, {'lives': 3, 'episode_frame_number': 588, 'frame_number': 588})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8142 - Steps 34 - infos : ({'lives': 2, 'episode_frame_number': 620, 'frame_number': 620}, {'lives': 2, 'episode_frame_number': 680, 'frame_number': 680}, {'lives': 2, 'episode_frame_number': 632, 'frame_number': 632}, {'lives': 3, 'episode_frame_number': 592, 'frame_number': 592})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8102 - Steps 35 - infos : ({'lives': 2, 'episode_frame_number': 624, 'frame_number': 624}, {'lives': 2, 'episode_frame_number': 684, 'frame_number': 684}, {'lives': 2, 'episode_frame_number': 636, 'frame_number': 636}, {'lives': 3, 'episode_frame_number': 596, 'frame_number': 596})
# Episode 1 - Avg Reward: 2.00 - Epsilon: 0.8061 - Steps 36 - infos : ({'lives': 2, 'episode_frame_number': 628, 'frame_number': 628}, {'lives': 2, 'episode_frame_number': 688, 'frame_number': 688}, {'lives': 2, 'episode_frame_number': 640, 'frame_number': 640}, {'lives': 3, 'episode_frame_number': 600, 'frame_number': 600})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.8021 - Steps 37 - infos : ({'lives': 2, 'episode_frame_number': 632, 'frame_number': 632}, {'lives': 2, 'episode_frame_number': 692, 'frame_number': 692}, {'lives': 2, 'episode_frame_number': 644, 'frame_number': 644}, {'lives': 2, 'episode_frame_number': 604, 'frame_number': 604})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7981 - Steps 38 - infos : ({'lives': 2, 'episode_frame_number': 636, 'frame_number': 636}, {'lives': 2, 'episode_frame_number': 696, 'frame_number': 696}, {'lives': 2, 'episode_frame_number': 648, 'frame_number': 648}, {'lives': 2, 'episode_frame_number': 608, 'frame_number': 608})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7941 - Steps 39 - infos : ({'lives': 2, 'episode_frame_number': 640, 'frame_number': 640}, {'lives': 2, 'episode_frame_number': 700, 'frame_number': 700}, {'lives': 2, 'episode_frame_number': 652, 'frame_number': 652}, {'lives': 2, 'episode_frame_number': 612, 'frame_number': 612})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7901 - Steps 40 - infos : ({'lives': 2, 'episode_frame_number': 644, 'frame_number': 644}, {'lives': 2, 'episode_frame_number': 704, 'frame_number': 704}, {'lives': 2, 'episode_frame_number': 656, 'frame_number': 656}, {'lives': 2, 'episode_frame_number': 616, 'frame_number': 616})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7862 - Steps 41 - infos : ({'lives': 2, 'episode_frame_number': 648, 'frame_number': 648}, {'lives': 2, 'episode_frame_number': 708, 'frame_number': 708}, {'lives': 2, 'episode_frame_number': 660, 'frame_number': 660}, {'lives': 2, 'episode_frame_number': 620, 'frame_number': 620})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7822 - Steps 42 - infos : ({'lives': 2, 'episode_frame_number': 652, 'frame_number': 652}, {'lives': 2, 'episode_frame_number': 712, 'frame_number': 712}, {'lives': 2, 'episode_frame_number': 664, 'frame_number': 664}, {'lives': 2, 'episode_frame_number': 624, 'frame_number': 624})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7783 - Steps 43 - infos : ({'lives': 2, 'episode_frame_number': 656, 'frame_number': 656}, {'lives': 2, 'episode_frame_number': 716, 'frame_number': 716}, {'lives': 2, 'episode_frame_number': 668, 'frame_number': 668}, {'lives': 2, 'episode_frame_number': 628, 'frame_number': 628})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7744 - Steps 44 - infos : ({'lives': 2, 'episode_frame_number': 660, 'frame_number': 660}, {'lives': 2, 'episode_frame_number': 720, 'frame_number': 720}, {'lives': 2, 'episode_frame_number': 672, 'frame_number': 672}, {'lives': 2, 'episode_frame_number': 632, 'frame_number': 632})
# Episode 1 - Avg Reward: 2.25 - Epsilon: 0.7705 - Steps 45 - infos : ({'lives': 2, 'episode_frame_number': 664, 'frame_number': 664}, {'lives': 2, 'episode_frame_number': 724, 'frame_number': 724}, {'lives': 2, 'episode_frame_number': 676, 'frame_number': 676}, {'lives': 2, 'episode_frame_number': 636, 'frame_number': 636})
# Episode 1 - Avg Reward: 2.50 - Epsilon: 0.7667 - Steps 46 - infos : ({'lives': 2, 'episode_frame_number': 668, 'frame_number': 668}, {'lives': 2, 'episode_frame_number': 728, 'frame_number': 728}, {'lives': 2, 'episode_frame_number': 680, 'frame_number': 680}, {'lives': 2, 'episode_frame_number': 640, 'frame_number': 640})
# Episode 1 - Avg Reward: 2.50 - Epsilon: 0.7629 - Steps 47 - infos : ({'lives': 2, 'episode_frame_number': 672, 'frame_number': 672}, {'lives': 2, 'episode_frame_number': 732, 'frame_number': 732}, {'lives': 2, 'episode_frame_number': 684, 'frame_number': 684}, {'lives': 2, 'episode_frame_number': 644, 'frame_number': 644})
# Episode 1 - Avg Reward: 2.50 - Epsilon: 0.7590 - Steps 48 - infos : ({'lives': 2, 'episode_frame_number': 676, 'frame_number': 676}, {'lives': 2, 'episode_frame_number': 736, 'frame_number': 736}, {'lives': 2, 'episode_frame_number': 688, 'frame_number': 688}, {'lives': 2, 'episode_frame_number': 648, 'frame_number': 648})
# Episode 1 - Avg Reward: 2.50 - Epsilon: 0.7553 - Steps 49 - infos : ({'lives': 2, 'episode_frame_number': 680, 'frame_number': 680}, {'lives': 2, 'episode_frame_number': 740, 'frame_number': 740}, {'lives': 2, 'episode_frame_number': 692, 'frame_number': 692}, {'lives': 2, 'episode_frame_number': 652, 'frame_number': 652})
# Episode 1 - Avg Reward: 2.75 - Epsilon: 0.7515 - Steps 50 - infos : ({'lives': 2, 'episode_frame_number': 684, 'frame_number': 684}, {'lives': 2, 'episode_frame_number': 744, 'frame_number': 744}, {'lives': 2, 'episode_frame_number': 696, 'frame_number': 696}, {'lives': 2, 'episode_frame_number': 656, 'frame_number': 656})
# Episode 1 - Avg Reward: 2.75 - Epsilon: 0.7477 - Steps 51 - infos : ({'lives': 2, 'episode_frame_number': 688, 'frame_number': 688}, {'lives': 2, 'episode_frame_number': 748, 'frame_number': 748}, {'lives': 2, 'episode_frame_number': 700, 'frame_number': 700}, {'lives': 2, 'episode_frame_number': 660, 'frame_number': 660})
# Episode 1 - Avg Reward: 2.75 - Epsilon: 0.7440 - Steps 52 - infos : ({'lives': 2, 'episode_frame_number': 692, 'frame_number': 692}, {'lives': 2, 'episode_frame_number': 752, 'frame_number': 752}, {'lives': 2, 'episode_frame_number': 704, 'frame_number': 704}, {'lives': 2, 'episode_frame_number': 664, 'frame_number': 664})
# Episode 1 - Avg Reward: 2.75 - Epsilon: 0.7403 - Steps 53 - infos : ({'lives': 2, 'episode_frame_number': 696, 'frame_number': 696}, {'lives': 2, 'episode_frame_number': 756, 'frame_number': 756}, {'lives': 2, 'episode_frame_number': 708, 'frame_number': 708}, {'lives': 2, 'episode_frame_number': 668, 'frame_number': 668})
# Episode 1 - Avg Reward: 2.75 - Epsilon: 0.7366 - Steps 54 - infos : ({'lives': 2, 'episode_frame_number': 700, 'frame_number': 700}, {'lives': 2, 'episode_frame_number': 760, 'frame_number': 760}, {'lives': 2, 'episode_frame_number': 712, 'frame_number': 712}, {'lives': 2, 'episode_frame_number': 672, 'frame_number': 672})
# Episode 1 - Avg Reward: 2.75 - Epsilon: 0.7329 - Steps 55 - infos : ({'lives': 2, 'episode_frame_number': 704, 'frame_number': 704}, {'lives': 2, 'episode_frame_number': 764, 'frame_number': 764}, {'lives': 2, 'episode_frame_number': 716, 'frame_number': 716}, {'lives': 2, 'episode_frame_number': 676, 'frame_number': 676})
# Episode 1 - Avg Reward: 3.00 - Epsilon: 0.7292 - Steps 56 - infos : ({'lives': 2, 'episode_frame_number': 708, 'frame_number': 708}, {'lives': 2, 'episode_frame_number': 768, 'frame_number': 768}, {'lives': 2, 'episode_frame_number': 720, 'frame_number': 720}, {'lives': 2, 'episode_frame_number': 680, 'frame_number': 680})
# Episode 1 - Avg Reward: 3.00 - Epsilon: 0.7256 - Steps 57 - infos : ({'lives': 2, 'episode_frame_number': 712, 'frame_number': 712}, {'lives': 2, 'episode_frame_number': 772, 'frame_number': 772}, {'lives': 2, 'episode_frame_number': 724, 'frame_number': 724}, {'lives': 2, 'episode_frame_number': 684, 'frame_number': 684})
# Episode 1 - Avg Reward: 3.00 - Epsilon: 0.7219 - Steps 58 - infos : ({'lives': 2, 'episode_frame_number': 716, 'frame_number': 716}, {'lives': 2, 'episode_frame_number': 776, 'frame_number': 776}, {'lives': 2, 'episode_frame_number': 728, 'frame_number': 728}, {'lives': 2, 'episode_frame_number': 688, 'frame_number': 688})
# Episode 1 - Avg Reward: 3.00 - Epsilon: 0.7183 - Steps 59 - infos : ({'lives': 2, 'episode_frame_number': 720, 'frame_number': 720}, {'lives': 2, 'episode_frame_number': 780, 'frame_number': 780}, {'lives': 2, 'episode_frame_number': 732, 'frame_number': 732}, {'lives': 2, 'episode_frame_number': 692, 'frame_number': 692})
# Episode 1 - Avg Reward: 3.25 - Epsilon: 0.7147 - Steps 60 - infos : ({'lives': 2, 'episode_frame_number': 724, 'frame_number': 724}, {'lives': 2, 'episode_frame_number': 784, 'frame_number': 784}, {'lives': 2, 'episode_frame_number': 736, 'frame_number': 736}, {'lives': 2, 'episode_frame_number': 696, 'frame_number': 696})
# Episode 1 - Avg Reward: 3.25 - Epsilon: 0.7112 - Steps 61 - infos : ({'lives': 2, 'episode_frame_number': 728, 'frame_number': 728}, {'lives': 2, 'episode_frame_number': 788, 'frame_number': 788}, {'lives': 2, 'episode_frame_number': 740, 'frame_number': 740}, {'lives': 2, 'episode_frame_number': 700, 'frame_number': 700})
# Episode 1 - Avg Reward: 3.50 - Epsilon: 0.7076 - Steps 62 - infos : ({'lives': 2, 'episode_frame_number': 732, 'frame_number': 732}, {'lives': 2, 'episode_frame_number': 792, 'frame_number': 792}, {'lives': 2, 'episode_frame_number': 744, 'frame_number': 744}, {'lives': 2, 'episode_frame_number': 704, 'frame_number': 704})
# Episode 1 - Avg Reward: 3.50 - Epsilon: 0.7041 - Steps 63 - infos : ({'lives': 2, 'episode_frame_number': 736, 'frame_number': 736}, {'lives': 2, 'episode_frame_number': 796, 'frame_number': 796}, {'lives': 2, 'episode_frame_number': 748, 'frame_number': 748}, {'lives': 2, 'episode_frame_number': 708, 'frame_number': 708})
# Episode 1 - Avg Reward: 3.75 - Epsilon: 0.7005 - Steps 64 - infos : ({'lives': 2, 'episode_frame_number': 740, 'frame_number': 740}, {'lives': 2, 'episode_frame_number': 800, 'frame_number': 800}, {'lives': 2, 'episode_frame_number': 752, 'frame_number': 752}, {'lives': 2, 'episode_frame_number': 712, 'frame_number': 712})
# Episode 1 - Avg Reward: 4.00 - Epsilon: 0.6970 - Steps 65 - infos : ({'lives': 2, 'episode_frame_number': 744, 'frame_number': 744}, {'lives': 2, 'episode_frame_number': 804, 'frame_number': 804}, {'lives': 2, 'episode_frame_number': 756, 'frame_number': 756}, {'lives': 2, 'episode_frame_number': 716, 'frame_number': 716})
# Episode 1 - Avg Reward: 4.00 - Epsilon: 0.6936 - Steps 66 - infos : ({'lives': 2, 'episode_frame_number': 748, 'frame_number': 748}, {'lives': 2, 'episode_frame_number': 808, 'frame_number': 808}, {'lives': 2, 'episode_frame_number': 760, 'frame_number': 760}, {'lives': 2, 'episode_frame_number': 720, 'frame_number': 720})
# Episode 1 - Avg Reward: 4.00 - Epsilon: 0.6901 - Steps 67 - infos : ({'lives': 2, 'episode_frame_number': 752, 'frame_number': 752}, {'lives': 2, 'episode_frame_number': 812, 'frame_number': 812}, {'lives': 2, 'episode_frame_number': 764, 'frame_number': 764}, {'lives': 2, 'episode_frame_number': 724, 'frame_number': 724})
# Episode 1 - Avg Reward: 4.00 - Epsilon: 0.6866 - Steps 68 - infos : ({'lives': 2, 'episode_frame_number': 756, 'frame_number': 756}, {'lives': 1, 'episode_frame_number': 816, 'frame_number': 816}, {'lives': 2, 'episode_frame_number': 768, 'frame_number': 768}, {'lives': 2, 'episode_frame_number': 728, 'frame_number': 728})
# Episode 1 - Avg Reward: 4.00 - Epsilon: 0.6832 - Steps 69 - infos : ({'lives': 2, 'episode_frame_number': 760, 'frame_number': 760}, {'lives': 1, 'episode_frame_number': 820, 'frame_number': 820}, {'lives': 1, 'episode_frame_number': 772, 'frame_number': 772}, {'lives': 2, 'episode_frame_number': 732, 'frame_number': 732})
# Episode 1 - Avg Reward: 4.00 - Epsilon: 0.6798 - Steps 70 - infos : ({'lives': 2, 'episode_frame_number': 764, 'frame_number': 764}, {'lives': 1, 'episode_frame_number': 824, 'frame_number': 824}, {'lives': 1, 'episode_frame_number': 776, 'frame_number': 776}, {'lives': 2, 'episode_frame_number': 736, 'frame_number': 736})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6764 - Steps 71 - infos : ({'lives': 2, 'episode_frame_number': 768, 'frame_number': 768}, {'lives': 1, 'episode_frame_number': 828, 'frame_number': 828}, {'lives': 1, 'episode_frame_number': 780, 'frame_number': 780}, {'lives': 2, 'episode_frame_number': 740, 'frame_number': 740})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6730 - Steps 72 - infos : ({'lives': 1, 'episode_frame_number': 772, 'frame_number': 772}, {'lives': 1, 'episode_frame_number': 832, 'frame_number': 832}, {'lives': 1, 'episode_frame_number': 784, 'frame_number': 784}, {'lives': 2, 'episode_frame_number': 744, 'frame_number': 744})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6696 - Steps 73 - infos : ({'lives': 1, 'episode_frame_number': 776, 'frame_number': 776}, {'lives': 1, 'episode_frame_number': 836, 'frame_number': 836}, {'lives': 1, 'episode_frame_number': 788, 'frame_number': 788}, {'lives': 2, 'episode_frame_number': 748, 'frame_number': 748})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6663 - Steps 74 - infos : ({'lives': 1, 'episode_frame_number': 780, 'frame_number': 780}, {'lives': 1, 'episode_frame_number': 840, 'frame_number': 840}, {'lives': 1, 'episode_frame_number': 792, 'frame_number': 792}, {'lives': 2, 'episode_frame_number': 752, 'frame_number': 752})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6630 - Steps 75 - infos : ({'lives': 1, 'episode_frame_number': 784, 'frame_number': 784}, {'lives': 1, 'episode_frame_number': 844, 'frame_number': 844}, {'lives': 1, 'episode_frame_number': 796, 'frame_number': 796}, {'lives': 2, 'episode_frame_number': 756, 'frame_number': 756})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6597 - Steps 76 - infos : ({'lives': 1, 'episode_frame_number': 788, 'frame_number': 788}, {'lives': 1, 'episode_frame_number': 848, 'frame_number': 848}, {'lives': 1, 'episode_frame_number': 800, 'frame_number': 800}, {'lives': 2, 'episode_frame_number': 760, 'frame_number': 760})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6564 - Steps 77 - infos : ({'lives': 1, 'episode_frame_number': 792, 'frame_number': 792}, {'lives': 1, 'episode_frame_number': 852, 'frame_number': 852}, {'lives': 1, 'episode_frame_number': 804, 'frame_number': 804}, {'lives': 2, 'episode_frame_number': 764, 'frame_number': 764})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6531 - Steps 78 - infos : ({'lives': 1, 'episode_frame_number': 796, 'frame_number': 796}, {'lives': 1, 'episode_frame_number': 856, 'frame_number': 856}, {'lives': 1, 'episode_frame_number': 808, 'frame_number': 808}, {'lives': 2, 'episode_frame_number': 768, 'frame_number': 768})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6498 - Steps 79 - infos : ({'lives': 1, 'episode_frame_number': 800, 'frame_number': 800}, {'lives': 1, 'episode_frame_number': 860, 'frame_number': 860}, {'lives': 1, 'episode_frame_number': 812, 'frame_number': 812}, {'lives': 2, 'episode_frame_number': 772, 'frame_number': 772})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6466 - Steps 80 - infos : ({'lives': 1, 'episode_frame_number': 804, 'frame_number': 804}, {'lives': 1, 'episode_frame_number': 864, 'frame_number': 864}, {'lives': 1, 'episode_frame_number': 816, 'frame_number': 816}, {'lives': 2, 'episode_frame_number': 776, 'frame_number': 776})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6433 - Steps 81 - infos : ({'lives': 1, 'episode_frame_number': 808, 'frame_number': 808}, {'lives': 1, 'episode_frame_number': 868, 'frame_number': 868}, {'lives': 1, 'episode_frame_number': 820, 'frame_number': 820}, {'lives': 2, 'episode_frame_number': 780, 'frame_number': 780})
# Episode 1 - Avg Reward: 4.25 - Epsilon: 0.6401 - Steps 82 - infos : ({'lives': 1, 'episode_frame_number': 812, 'frame_number': 812}, {'lives': 1, 'episode_frame_number': 872, 'frame_number': 872}, {'lives': 1, 'episode_frame_number': 824, 'frame_number': 824}, {'lives': 2, 'episode_frame_number': 784, 'frame_number': 784})
# Episode 1 - Avg Reward: 4.50 - Epsilon: 0.6369 - Steps 83 - infos : ({'lives': 1, 'episode_frame_number': 816, 'frame_number': 816}, {'lives': 1, 'episode_frame_number': 876, 'frame_number': 876}, {'lives': 1, 'episode_frame_number': 828, 'frame_number': 828}, {'lives': 2, 'episode_frame_number': 788, 'frame_number': 788})
# Episode 1 - Avg Reward: 4.50 - Epsilon: 0.6337 - Steps 84 - infos : ({'lives': 1, 'episode_frame_number': 820, 'frame_number': 820}, {'lives': 1, 'episode_frame_number': 880, 'frame_number': 880}, {'lives': 1, 'episode_frame_number': 832, 'frame_number': 832}, {'lives': 2, 'episode_frame_number': 792, 'frame_number': 792})
# Episode 1 - Avg Reward: 4.50 - Epsilon: 0.6306 - Steps 85 - infos : ({'lives': 1, 'episode_frame_number': 824, 'frame_number': 824}, {'lives': 1, 'episode_frame_number': 884, 'frame_number': 884}, {'lives': 1, 'episode_frame_number': 836, 'frame_number': 836}, {'lives': 1, 'episode_frame_number': 796, 'frame_number': 796})
# Episode 1 - Avg Reward: 4.50 - Epsilon: 0.6274 - Steps 86 - infos : ({'lives': 1, 'episode_frame_number': 828, 'frame_number': 828}, {'lives': 1, 'episode_frame_number': 888, 'frame_number': 888}, {'lives': 1, 'episode_frame_number': 840, 'frame_number': 840}, {'lives': 1, 'episode_frame_number': 800, 'frame_number': 800})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6243 - Steps 87 - infos : ({'lives': 1, 'episode_frame_number': 832, 'frame_number': 832}, {'lives': 0, 'episode_frame_number': 892, 'frame_number': 892}, {'lives': 1, 'episode_frame_number': 844, 'frame_number': 844}, {'lives': 1, 'episode_frame_number': 804, 'frame_number': 804})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6211 - Steps 88 - infos : ({'lives': 1, 'episode_frame_number': 836, 'frame_number': 836}, {'lives': 0, 'episode_frame_number': 896, 'frame_number': 896}, {'lives': 1, 'episode_frame_number': 848, 'frame_number': 848}, {'lives': 1, 'episode_frame_number': 808, 'frame_number': 808})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6180 - Steps 89 - infos : ({'lives': 1, 'episode_frame_number': 840, 'frame_number': 840}, {'lives': 0, 'episode_frame_number': 900, 'frame_number': 900}, {'lives': 0, 'episode_frame_number': 852, 'frame_number': 852}, {'lives': 1, 'episode_frame_number': 812, 'frame_number': 812})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6149 - Steps 90 - infos : ({'lives': 1, 'episode_frame_number': 844, 'frame_number': 844}, {'lives': 0, 'episode_frame_number': 904, 'frame_number': 904}, {'lives': 0, 'episode_frame_number': 856, 'frame_number': 856}, {'lives': 1, 'episode_frame_number': 816, 'frame_number': 816})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6119 - Steps 91 - infos : ({'lives': 1, 'episode_frame_number': 848, 'frame_number': 848}, {'lives': 0, 'episode_frame_number': 908, 'frame_number': 908}, {'lives': 0, 'episode_frame_number': 860, 'frame_number': 860}, {'lives': 1, 'episode_frame_number': 820, 'frame_number': 820})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6088 - Steps 92 - infos : ({'lives': 1, 'episode_frame_number': 852, 'frame_number': 852}, {'lives': 0, 'episode_frame_number': 912, 'frame_number': 912}, {'lives': 0, 'episode_frame_number': 864, 'frame_number': 864}, {'lives': 1, 'episode_frame_number': 824, 'frame_number': 824})
# Episode 1 - Avg Reward: 5.00 - Epsilon: 0.6058 - Steps 93 - infos : ({'lives': 1, 'episode_frame_number': 856, 'frame_number': 856}, {'lives': 0, 'episode_frame_number': 916, 'frame_number': 916}, {'lives': 0, 'episode_frame_number': 868, 'frame_number': 868}, {'lives': 1, 'episode_frame_number': 828, 'frame_number': 828})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.6027 - Steps 94 - infos : ({'lives': 0, 'episode_frame_number': 860, 'frame_number': 860}, {'lives': 0, 'episode_frame_number': 920, 'frame_number': 920}, {'lives': 0, 'episode_frame_number': 872, 'frame_number': 872}, {'lives': 1, 'episode_frame_number': 832, 'frame_number': 832})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5997 - Steps 95 - infos : ({'lives': 0, 'episode_frame_number': 864, 'frame_number': 864}, {'lives': 0, 'episode_frame_number': 924, 'frame_number': 924}, {'lives': 0, 'episode_frame_number': 876, 'frame_number': 876}, {'lives': 1, 'episode_frame_number': 836, 'frame_number': 836})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5967 - Steps 96 - infos : ({'lives': 0, 'episode_frame_number': 868, 'frame_number': 868}, {'lives': 0, 'episode_frame_number': 928, 'frame_number': 928}, {'lives': 0, 'episode_frame_number': 880, 'frame_number': 880}, {'lives': 1, 'episode_frame_number': 840, 'frame_number': 840})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5937 - Steps 97 - infos : ({'lives': 0, 'episode_frame_number': 872, 'frame_number': 872}, {'lives': 0, 'episode_frame_number': 932, 'frame_number': 932}, {'lives': 0, 'episode_frame_number': 884, 'frame_number': 884}, {'lives': 1, 'episode_frame_number': 844, 'frame_number': 844})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5908 - Steps 98 - infos : ({'lives': 0, 'episode_frame_number': 876, 'frame_number': 876}, {'lives': 0, 'episode_frame_number': 936, 'frame_number': 936}, {'lives': 0, 'episode_frame_number': 888, 'frame_number': 888}, {'lives': 1, 'episode_frame_number': 848, 'frame_number': 848})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5878 - Steps 99 - infos : ({'lives': 0, 'episode_frame_number': 880, 'frame_number': 880}, {'lives': 0, 'episode_frame_number': 940, 'frame_number': 940}, {'lives': 0, 'episode_frame_number': 892, 'frame_number': 892}, {'lives': 1, 'episode_frame_number': 852, 'frame_number': 852})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5849 - Steps 100 - infos : ({'lives': 0, 'episode_frame_number': 884, 'frame_number': 884}, {'lives': 0, 'episode_frame_number': 944, 'frame_number': 944}, {'lives': 0, 'episode_frame_number': 896, 'frame_number': 896}, {'lives': 1, 'episode_frame_number': 856, 'frame_number': 856})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5820 - Steps 101 - infos : ({'lives': 0, 'episode_frame_number': 888, 'frame_number': 888}, {'lives': 0, 'episode_frame_number': 948, 'frame_number': 948}, {'lives': 0, 'episode_frame_number': 900, 'frame_number': 900}, {'lives': 1, 'episode_frame_number': 860, 'frame_number': 860})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5790 - Steps 102 - infos : ({'lives': 0, 'episode_frame_number': 892, 'frame_number': 892}, {'lives': 0, 'episode_frame_number': 952, 'frame_number': 952}, {'lives': 0, 'episode_frame_number': 904, 'frame_number': 904}, {'lives': 1, 'episode_frame_number': 864, 'frame_number': 864})
# Episode 1 - Avg Reward: 5.25 - Epsilon: 0.5762 - Steps 103 - infos : ({'lives': 0, 'episode_frame_number': 896, 'frame_number': 896}, {'lives': 0, 'episode_frame_number': 956, 'frame_number': 956}, {'lives': 0, 'episode_frame_number': 908, 'frame_number': 908}, {'lives': 1, 'episode_frame_number': 868, 'frame_number': 868})
# All died...loading next episode
# Main process sending reset command...
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Main process waiting for response...
# Main process received observation with shape: (84, 84, 1)
# Episode 2 - Avg Reward: 0.00 - Epsilon: 0.5733 - Steps 104 - infos : ({'lives': 4, 'episode_frame_number': 428, 'frame_number': 1328}, {'lives': 4, 'episode_frame_number': 468, 'frame_number': 1428}, {'lives': 4, 'episode_frame_number': 448, 'frame_number': 1360}, {'lives': 4, 'episode_frame_number': 500, 'frame_number': 1372})
# Episode 2 - Avg Reward: 0.00 - Epsilon: 0.5704 - Steps 105 - infos : ({'lives': 4, 'episode_frame_number': 432, 'frame_number': 1332}, {'lives': 4, 'episode_frame_number': 472, 'frame_number': 1432}, {'lives': 4, 'episode_frame_number': 452, 'frame_number': 1364}, {'lives': 4, 'episode_frame_number': 504, 'frame_number': 1376})
# Episode 2 - Avg Reward: 0.50 - Epsilon: 0.5676 - Steps 106 - infos : ({'lives': 4, 'episode_frame_number': 436, 'frame_number': 1336}, {'lives': 4, 'episode_frame_number': 476, 'frame_number': 1436}, {'lives': 4, 'episode_frame_number': 456, 'frame_number': 1368}, {'lives': 4, 'episode_frame_number': 508, 'frame_number': 1380})
# Episode 2 - Avg Reward: 0.75 - Epsilon: 0.5647 - Steps 107 - infos : ({'lives': 4, 'episode_frame_number': 440, 'frame_number': 1340}, {'lives': 4, 'episode_frame_number': 480, 'frame_number': 1440}, {'lives': 3, 'episode_frame_number': 460, 'frame_number': 1372}, {'lives': 4, 'episode_frame_number': 512, 'frame_number': 1384})
# Episode 2 - Avg Reward: 1.00 - Epsilon: 0.5619 - Steps 108 - infos : ({'lives': 4, 'episode_frame_number': 444, 'frame_number': 1344}, {'lives': 3, 'episode_frame_number': 484, 'frame_number': 1444}, {'lives': 3, 'episode_frame_number': 464, 'frame_number': 1376}, {'lives': 4, 'episode_frame_number': 516, 'frame_number': 1388})
# Episode 2 - Avg Reward: 1.00 - Epsilon: 0.5591 - Steps 109 - infos : ({'lives': 4, 'episode_frame_number': 448, 'frame_number': 1348}, {'lives': 3, 'episode_frame_number': 488, 'frame_number': 1448}, {'lives': 3, 'episode_frame_number': 468, 'frame_number': 1380}, {'lives': 4, 'episode_frame_number': 520, 'frame_number': 1392})
# Episode 2 - Avg Reward: 1.00 - Epsilon: 0.5563 - Steps 110 - infos : ({'lives': 4, 'episode_frame_number': 452, 'frame_number': 1352}, {'lives': 3, 'episode_frame_number': 492, 'frame_number': 1452}, {'lives': 3, 'episode_frame_number': 472, 'frame_number': 1384}, {'lives': 4, 'episode_frame_number': 524, 'frame_number': 1396})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5535 - Steps 111 - infos : ({'lives': 3, 'episode_frame_number': 456, 'frame_number': 1356}, {'lives': 3, 'episode_frame_number': 496, 'frame_number': 1456}, {'lives': 3, 'episode_frame_number': 476, 'frame_number': 1388}, {'lives': 3, 'episode_frame_number': 528, 'frame_number': 1400})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5507 - Steps 112 - infos : ({'lives': 3, 'episode_frame_number': 460, 'frame_number': 1360}, {'lives': 3, 'episode_frame_number': 500, 'frame_number': 1460}, {'lives': 3, 'episode_frame_number': 480, 'frame_number': 1392}, {'lives': 3, 'episode_frame_number': 532, 'frame_number': 1404})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5480 - Steps 113 - infos : ({'lives': 3, 'episode_frame_number': 464, 'frame_number': 1364}, {'lives': 3, 'episode_frame_number': 504, 'frame_number': 1464}, {'lives': 3, 'episode_frame_number': 484, 'frame_number': 1396}, {'lives': 3, 'episode_frame_number': 536, 'frame_number': 1408})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5452 - Steps 114 - infos : ({'lives': 3, 'episode_frame_number': 468, 'frame_number': 1368}, {'lives': 3, 'episode_frame_number': 508, 'frame_number': 1468}, {'lives': 3, 'episode_frame_number': 488, 'frame_number': 1400}, {'lives': 3, 'episode_frame_number': 540, 'frame_number': 1412})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5425 - Steps 115 - infos : ({'lives': 3, 'episode_frame_number': 472, 'frame_number': 1372}, {'lives': 3, 'episode_frame_number': 512, 'frame_number': 1472}, {'lives': 3, 'episode_frame_number': 492, 'frame_number': 1404}, {'lives': 3, 'episode_frame_number': 544, 'frame_number': 1416})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5398 - Steps 116 - infos : ({'lives': 3, 'episode_frame_number': 476, 'frame_number': 1376}, {'lives': 3, 'episode_frame_number': 516, 'frame_number': 1476}, {'lives': 3, 'episode_frame_number': 496, 'frame_number': 1408}, {'lives': 3, 'episode_frame_number': 548, 'frame_number': 1420})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5371 - Steps 117 - infos : ({'lives': 3, 'episode_frame_number': 480, 'frame_number': 1380}, {'lives': 3, 'episode_frame_number': 520, 'frame_number': 1480}, {'lives': 3, 'episode_frame_number': 500, 'frame_number': 1412}, {'lives': 3, 'episode_frame_number': 552, 'frame_number': 1424})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5344 - Steps 118 - infos : ({'lives': 3, 'episode_frame_number': 484, 'frame_number': 1384}, {'lives': 3, 'episode_frame_number': 524, 'frame_number': 1484}, {'lives': 3, 'episode_frame_number': 504, 'frame_number': 1416}, {'lives': 3, 'episode_frame_number': 556, 'frame_number': 1428})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5318 - Steps 119 - infos : ({'lives': 3, 'episode_frame_number': 488, 'frame_number': 1388}, {'lives': 3, 'episode_frame_number': 528, 'frame_number': 1488}, {'lives': 3, 'episode_frame_number': 508, 'frame_number': 1420}, {'lives': 3, 'episode_frame_number': 560, 'frame_number': 1432})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5291 - Steps 120 - infos : ({'lives': 3, 'episode_frame_number': 492, 'frame_number': 1392}, {'lives': 3, 'episode_frame_number': 532, 'frame_number': 1492}, {'lives': 3, 'episode_frame_number': 512, 'frame_number': 1424}, {'lives': 3, 'episode_frame_number': 564, 'frame_number': 1436})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5264 - Steps 121 - infos : ({'lives': 3, 'episode_frame_number': 496, 'frame_number': 1396}, {'lives': 3, 'episode_frame_number': 536, 'frame_number': 1496}, {'lives': 3, 'episode_frame_number': 516, 'frame_number': 1428}, {'lives': 3, 'episode_frame_number': 568, 'frame_number': 1440})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5238 - Steps 122 - infos : ({'lives': 3, 'episode_frame_number': 500, 'frame_number': 1400}, {'lives': 3, 'episode_frame_number': 540, 'frame_number': 1500}, {'lives': 3, 'episode_frame_number': 520, 'frame_number': 1432}, {'lives': 3, 'episode_frame_number': 572, 'frame_number': 1444})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5212 - Steps 123 - infos : ({'lives': 3, 'episode_frame_number': 504, 'frame_number': 1404}, {'lives': 3, 'episode_frame_number': 544, 'frame_number': 1504}, {'lives': 3, 'episode_frame_number': 524, 'frame_number': 1436}, {'lives': 3, 'episode_frame_number': 576, 'frame_number': 1448})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5186 - Steps 124 - infos : ({'lives': 3, 'episode_frame_number': 508, 'frame_number': 1408}, {'lives': 3, 'episode_frame_number': 548, 'frame_number': 1508}, {'lives': 3, 'episode_frame_number': 528, 'frame_number': 1440}, {'lives': 3, 'episode_frame_number': 580, 'frame_number': 1452})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5160 - Steps 125 - infos : ({'lives': 3, 'episode_frame_number': 512, 'frame_number': 1412}, {'lives': 3, 'episode_frame_number': 552, 'frame_number': 1512}, {'lives': 3, 'episode_frame_number': 532, 'frame_number': 1444}, {'lives': 3, 'episode_frame_number': 584, 'frame_number': 1456})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5134 - Steps 126 - infos : ({'lives': 3, 'episode_frame_number': 516, 'frame_number': 1416}, {'lives': 3, 'episode_frame_number': 556, 'frame_number': 1516}, {'lives': 3, 'episode_frame_number': 536, 'frame_number': 1448}, {'lives': 3, 'episode_frame_number': 588, 'frame_number': 1460})
# Episode 2 - Avg Reward: 1.25 - Epsilon: 0.5108 - Steps 127 - infos : ({'lives': 3, 'episode_frame_number': 520, 'frame_number': 1420}, {'lives': 3, 'episode_frame_number': 560, 'frame_number': 1520}, {'lives': 3, 'episode_frame_number': 540, 'frame_number': 1452}, {'lives': 3, 'episode_frame_number': 592, 'frame_number': 1464})
# Episode 2 - Avg Reward: 1.50 - Epsilon: 0.5083 - Steps 128 - infos : ({'lives': 3, 'episode_frame_number': 524, 'frame_number': 1424}, {'lives': 3, 'episode_frame_number': 564, 'frame_number': 1524}, {'lives': 3, 'episode_frame_number': 544, 'frame_number': 1456}, {'lives': 3, 'episode_frame_number': 596, 'frame_number': 1468})
# Episode 2 - Avg Reward: 1.75 - Epsilon: 0.5058 - Steps 129 - infos : ({'lives': 3, 'episode_frame_number': 528, 'frame_number': 1428}, {'lives': 3, 'episode_frame_number': 568, 'frame_number': 1528}, {'lives': 2, 'episode_frame_number': 548, 'frame_number': 1460}, {'lives': 3, 'episode_frame_number': 600, 'frame_number': 1472})
# Episode 2 - Avg Reward: 1.75 - Epsilon: 0.5032 - Steps 130 - infos : ({'lives': 3, 'episode_frame_number': 532, 'frame_number': 1432}, {'lives': 3, 'episode_frame_number': 572, 'frame_number': 1532}, {'lives': 2, 'episode_frame_number': 552, 'frame_number': 1464}, {'lives': 2, 'episode_frame_number': 604, 'frame_number': 1476})
# Episode 2 - Avg Reward: 1.75 - Epsilon: 0.5007 - Steps 131 - infos : ({'lives': 3, 'episode_frame_number': 536, 'frame_number': 1436}, {'lives': 3, 'episode_frame_number': 576, 'frame_number': 1536}, {'lives': 2, 'episode_frame_number': 556, 'frame_number': 1468}, {'lives': 2, 'episode_frame_number': 608, 'frame_number': 1480})
# Episode 2 - Avg Reward: 1.75 - Epsilon: 0.4982 - Steps 132 - infos : ({'lives': 3, 'episode_frame_number': 540, 'frame_number': 1440}, {'lives': 3, 'episode_frame_number': 580, 'frame_number': 1540}, {'lives': 2, 'episode_frame_number': 560, 'frame_number': 1472}, {'lives': 2, 'episode_frame_number': 612, 'frame_number': 1484})
# Episode 2 - Avg Reward: 2.00 - Epsilon: 0.4957 - Steps 133 - infos : ({'lives': 3, 'episode_frame_number': 544, 'frame_number': 1444}, {'lives': 2, 'episode_frame_number': 584, 'frame_number': 1544}, {'lives': 2, 'episode_frame_number': 564, 'frame_number': 1476}, {'lives': 2, 'episode_frame_number': 616, 'frame_number': 1488})
# Episode 2 - Avg Reward: 2.25 - Epsilon: 0.4932 - Steps 134 - infos : ({'lives': 3, 'episode_frame_number': 548, 'frame_number': 1448}, {'lives': 2, 'episode_frame_number': 588, 'frame_number': 1548}, {'lives': 2, 'episode_frame_number': 568, 'frame_number': 1480}, {'lives': 2, 'episode_frame_number': 620, 'frame_number': 1492})
# Episode 2 - Avg Reward: 2.25 - Epsilon: 0.4908 - Steps 135 - infos : ({'lives': 3, 'episode_frame_number': 552, 'frame_number': 1452}, {'lives': 2, 'episode_frame_number': 592, 'frame_number': 1552}, {'lives': 2, 'episode_frame_number': 572, 'frame_number': 1484}, {'lives': 2, 'episode_frame_number': 624, 'frame_number': 1496})
# Episode 2 - Avg Reward: 2.25 - Epsilon: 0.4883 - Steps 136 - infos : ({'lives': 3, 'episode_frame_number': 556, 'frame_number': 1456}, {'lives': 2, 'episode_frame_number': 596, 'frame_number': 1556}, {'lives': 2, 'episode_frame_number': 576, 'frame_number': 1488}, {'lives': 2, 'episode_frame_number': 628, 'frame_number': 1500})
# Episode 2 - Avg Reward: 2.25 - Epsilon: 0.4859 - Steps 137 - infos : ({'lives': 3, 'episode_frame_number': 560, 'frame_number': 1460}, {'lives': 2, 'episode_frame_number': 600, 'frame_number': 1560}, {'lives': 2, 'episode_frame_number': 580, 'frame_number': 1492}, {'lives': 2, 'episode_frame_number': 632, 'frame_number': 1504})
# ...
# Episode 27 - Avg Reward: 4.50 - Epsilon: 0.1000 - Steps 3882 - infos : ({'lives': 2, 'episode_frame_number': 824, 'frame_number': 27144}, {'lives': 2, 'episode_frame_number': 828, 'frame_number': 26822}, {'lives': 4, 'episode_frame_number': 828, 'frame_number': 27380}, {'lives': 1, 'episode_frame_number': 800, 'frame_number': 26908})
# Episode 27 - Avg Reward: 4.50 - Epsilon: 0.1000 - Steps 3883 - infos : ({'lives': 2, 'episode_frame_number': 828, 'frame_number': 27148}, {'lives': 2, 'episode_frame_number': 832, 'frame_number': 26826}, {'lives': 4, 'episode_frame_number': 832, 'frame_number': 27384}, {'lives': 1, 'episode_frame_number': 804, 'frame_number': 26912})
# Episode 27 - Avg Reward: 4.75 - Epsilon: 0.1000 - Steps 3884 - infos : ({'lives': 2, 'episode_frame_number': 832, 'frame_number': 27152}, {'lives': 1, 'episode_frame_number': 836, 'frame_number': 26830}, {'lives': 3, 'episode_frame_number': 836, 'frame_number': 27388}, {'lives': 1, 'episode_frame_number': 808, 'frame_number': 26916})
# Episode 27 - Avg Reward: 4.75 - Epsilon: 0.1000 - Steps 3885 - infos : ({'lives': 2, 'episode_frame_number': 836, 'frame_number': 27156}, {'lives': 1, 'episode_frame_number': 840, 'frame_number': 26834}, {'lives': 3, 'episode_frame_number': 840, 'frame_number': 27392}, {'lives': 1, 'episode_frame_number': 812, 'frame_number': 26920})
# Episode 27 - Avg Reward: 4.75 - Epsilon: 0.1000 - Steps 3886 - infos : ({'lives': 2, 'episode_frame_number': 840, 'frame_number': 27160}, {'lives': 1, 'episode_frame_number': 844, 'frame_number': 26838}, {'lives': 3, 'episode_frame_number': 844, 'frame_number': 27396}, {'lives': 1, 'episode_frame_number': 816, 'frame_number': 26924})
# Episode 27 - Avg Reward: 4.75 - Epsilon: 0.1000 - Steps 3887 - infos : ({'lives': 2, 'episode_frame_number': 844, 'frame_number': 27164}, {'lives': 1, 'episode_frame_number': 848, 'frame_number': 26842}, {'lives': 3, 'episode_frame_number': 848, 'frame_number': 27400}, {'lives': 1, 'episode_frame_number': 820, 'frame_number': 26928})
# Episode 27 - Avg Reward: 4.75 - Epsilon: 0.1000 - Steps 3888 - infos : ({'lives': 2, 'episode_frame_number': 848, 'frame_number': 27168}, {'lives': 1, 'episode_frame_number': 852, 'frame_number': 26846}, {'lives': 3, 'episode_frame_number': 852, 'frame_number': 27404}, {'lives': 1, 'episode_frame_number': 824, 'frame_number': 26932})
# Episode 27 - Avg Reward: 5.00 - Epsilon: 0.1000 - Steps 3889 - infos : ({'lives': 2, 'episode_frame_number': 852, 'frame_number': 27172}, {'lives': 1, 'episode_frame_number': 856, 'frame_number': 26850}, {'lives': 3, 'episode_frame_number': 856, 'frame_number': 27408}, {'lives': 1, 'episode_frame_number': 828, 'frame_number': 26936})
# Episode 27 - Avg Reward: 5.00 - Epsilon: 0.1000 - Steps 3890 - infos : ({'lives': 2, 'episode_frame_number': 856, 'frame_number': 27176}, {'lives': 1, 'episode_frame_number': 860, 'frame_number': 26854}, {'lives': 3, 'episode_frame_number': 860, 'frame_number': 27412}, {'lives': 1, 'episode_frame_number': 832, 'frame_number': 26940})
# Episode 27 - Avg Reward: 5.00 - Epsilon: 0.1000 - Steps 3891 - infos : ({'lives': 2, 'episode_frame_number': 860, 'frame_number': 27180}, {'lives': 1, 'episode_frame_number': 864, 'frame_number': 26858}, {'lives': 3, 'episode_frame_number': 864, 'frame_number': 27416}, {'lives': 1, 'episode_frame_number': 836, 'frame_number': 26944})
# Episode 27 - Avg Reward: 5.00 - Epsilon: 0.1000 - Steps 3892 - infos : ({'lives': 2, 'episode_frame_number': 864, 'frame_number': 27184}, {'lives': 1, 'episode_frame_number': 868, 'frame_number': 26862}, {'lives': 3, 'episode_frame_number': 868, 'frame_number': 27420}, {'lives': 1, 'episode_frame_number': 840, 'frame_number': 26948})
# Episode 27 - Avg Reward: 5.25 - Epsilon: 0.1000 - Steps 3893 - infos : ({'lives': 1, 'episode_frame_number': 868, 'frame_number': 27188}, {'lives': 1, 'episode_frame_number': 872, 'frame_number': 26866}, {'lives': 3, 'episode_frame_number': 872, 'frame_number': 27424}, {'lives': 1, 'episode_frame_number': 844, 'frame_number': 26952})
# Episode 27 - Avg Reward: 5.25 - Epsilon: 0.1000 - Steps 3894 - infos : ({'lives': 1, 'episode_frame_number': 872, 'frame_number': 27192}, {'lives': 1, 'episode_frame_number': 876, 'frame_number': 26870}, {'lives': 3, 'episode_frame_number': 876, 'frame_number': 27428}, {'lives': 1, 'episode_frame_number': 848, 'frame_number': 26956})
# Episode 27 - Avg Reward: 5.25 - Epsilon: 0.1000 - Steps 3895 - infos : ({'lives': 1, 'episode_frame_number': 876, 'frame_number': 27196}, {'lives': 1, 'episode_frame_number': 880, 'frame_number': 26874}, {'lives': 3, 'episode_frame_number': 880, 'frame_number': 27432}, {'lives': 1, 'episode_frame_number': 852, 'frame_number': 26960})
# Episode 27 - Avg Reward: 5.25 - Epsilon: 0.1000 - Steps 3896 - infos : ({'lives': 1, 'episode_frame_number': 880, 'frame_number': 27200}, {'lives': 1, 'episode_frame_number': 884, 'frame_number': 26878}, {'lives': 3, 'episode_frame_number': 884, 'frame_number': 27436}, {'lives': 1, 'episode_frame_number': 856, 'frame_number': 26964})
# Episode 27 - Avg Reward: 5.50 - Epsilon: 0.1000 - Steps 3897 - infos : ({'lives': 1, 'episode_frame_number': 884, 'frame_number': 27204}, {'lives': 1, 'episode_frame_number': 888, 'frame_number': 26882}, {'lives': 3, 'episode_frame_number': 888, 'frame_number': 27440}, {'lives': 1, 'episode_frame_number': 860, 'frame_number': 26968})
# Episode 27 - Avg Reward: 5.50 - Epsilon: 0.1000 - Steps 3898 - infos : ({'lives': 1, 'episode_frame_number': 888, 'frame_number': 27208}, {'lives': 1, 'episode_frame_number': 892, 'frame_number': 26886}, {'lives': 3, 'episode_frame_number': 892, 'frame_number': 27444}, {'lives': 1, 'episode_frame_number': 864, 'frame_number': 26972})
# Episode 27 - Avg Reward: 5.75 - Epsilon: 0.1000 - Steps 3899 - infos : ({'lives': 1, 'episode_frame_number': 892, 'frame_number': 27212}, {'lives': 1, 'episode_frame_number': 896, 'frame_number': 26890}, {'lives': 3, 'episode_frame_number': 896, 'frame_number': 27448}, {'lives': 1, 'episode_frame_number': 868, 'frame_number': 26976})
# Episode 27 - Avg Reward: 5.75 - Epsilon: 0.1000 - Steps 3900 - infos : ({'lives': 1, 'episode_frame_number': 896, 'frame_number': 27216}, {'lives': 1, 'episode_frame_number': 900, 'frame_number': 26894}, {'lives': 3, 'episode_frame_number': 900, 'frame_number': 27452}, {'lives': 1, 'episode_frame_number': 872, 'frame_number': 26980})
# Episode 27 - Avg Reward: 5.75 - Epsilon: 0.1000 - Steps 3901 - infos : ({'lives': 1, 'episode_frame_number': 900, 'frame_number': 27220}, {'lives': 1, 'episode_frame_number': 904, 'frame_number': 26898}, {'lives': 3, 'episode_frame_number': 904, 'frame_number': 27456}, {'lives': 1, 'episode_frame_number': 876, 'frame_number': 26984})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3902 - infos : ({'lives': 1, 'episode_frame_number': 904, 'frame_number': 27224}, {'lives': 1, 'episode_frame_number': 908, 'frame_number': 26902}, {'lives': 3, 'episode_frame_number': 908, 'frame_number': 27460}, {'lives': 1, 'episode_frame_number': 880, 'frame_number': 26988})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3903 - infos : ({'lives': 1, 'episode_frame_number': 908, 'frame_number': 27228}, {'lives': 1, 'episode_frame_number': 912, 'frame_number': 26906}, {'lives': 2, 'episode_frame_number': 912, 'frame_number': 27464}, {'lives': 1, 'episode_frame_number': 884, 'frame_number': 26992})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3904 - infos : ({'lives': 1, 'episode_frame_number': 912, 'frame_number': 27232}, {'lives': 1, 'episode_frame_number': 916, 'frame_number': 26910}, {'lives': 2, 'episode_frame_number': 916, 'frame_number': 27468}, {'lives': 1, 'episode_frame_number': 888, 'frame_number': 26996})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3905 - infos : ({'lives': 1, 'episode_frame_number': 916, 'frame_number': 27236}, {'lives': 1, 'episode_frame_number': 920, 'frame_number': 26914}, {'lives': 2, 'episode_frame_number': 920, 'frame_number': 27472}, {'lives': 1, 'episode_frame_number': 892, 'frame_number': 27000})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3906 - infos : ({'lives': 1, 'episode_frame_number': 920, 'frame_number': 27240}, {'lives': 1, 'episode_frame_number': 924, 'frame_number': 26918}, {'lives': 2, 'episode_frame_number': 924, 'frame_number': 27476}, {'lives': 1, 'episode_frame_number': 896, 'frame_number': 27004})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3907 - infos : ({'lives': 1, 'episode_frame_number': 924, 'frame_number': 27244}, {'lives': 1, 'episode_frame_number': 928, 'frame_number': 26922}, {'lives': 2, 'episode_frame_number': 928, 'frame_number': 27480}, {'lives': 1, 'episode_frame_number': 900, 'frame_number': 27008})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3908 - infos : ({'lives': 1, 'episode_frame_number': 928, 'frame_number': 27248}, {'lives': 1, 'episode_frame_number': 932, 'frame_number': 26926}, {'lives': 2, 'episode_frame_number': 932, 'frame_number': 27484}, {'lives': 1, 'episode_frame_number': 904, 'frame_number': 27012})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3909 - infos : ({'lives': 1, 'episode_frame_number': 932, 'frame_number': 27252}, {'lives': 1, 'episode_frame_number': 936, 'frame_number': 26930}, {'lives': 2, 'episode_frame_number': 936, 'frame_number': 27488}, {'lives': 1, 'episode_frame_number': 908, 'frame_number': 27016})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3910 - infos : ({'lives': 1, 'episode_frame_number': 936, 'frame_number': 27256}, {'lives': 1, 'episode_frame_number': 940, 'frame_number': 26934}, {'lives': 2, 'episode_frame_number': 940, 'frame_number': 27492}, {'lives': 1, 'episode_frame_number': 912, 'frame_number': 27020})
# Episode 27 - Avg Reward: 6.00 - Epsilon: 0.1000 - Steps 3911 - infos : ({'lives': 1, 'episode_frame_number': 940, 'frame_number': 27260}, {'lives': 1, 'episode_frame_number': 944, 'frame_number': 26938}, {'lives': 2, 'episode_frame_number': 944, 'frame_number': 27496}, {'lives': 1, 'episode_frame_number': 916, 'frame_number': 27024})
# Episode 27 - Avg Reward: 6.25 - Epsilon: 0.1000 - Steps 3912 - infos : ({'lives': 1, 'episode_frame_number': 944, 'frame_number': 27264}, {'lives': 1, 'episode_frame_number': 948, 'frame_number': 26942}, {'lives': 2, 'episode_frame_number': 948, 'frame_number': 27500}, {'lives': 1, 'episode_frame_number': 920, 'frame_number': 27028})
# Episode 27 - Avg Reward: 6.50 - Epsilon: 0.1000 - Steps 3913 - infos : ({'lives': 1, 'episode_frame_number': 948, 'frame_number': 27268}, {'lives': 1, 'episode_frame_number': 952, 'frame_number': 26946}, {'lives': 2, 'episode_frame_number': 952, 'frame_number': 27504}, {'lives': 1, 'episode_frame_number': 924, 'frame_number': 27032})
# Episode 27 - Avg Reward: 6.50 - Epsilon: 0.1000 - Steps 3914 - infos : ({'lives': 1, 'episode_frame_number': 952, 'frame_number': 27272}, {'lives': 1, 'episode_frame_number': 956, 'frame_number': 26950}, {'lives': 2, 'episode_frame_number': 956, 'frame_number': 27508}, {'lives': 1, 'episode_frame_number': 928, 'frame_number': 27036})
# Episode 27 - Avg Reward: 6.75 - Epsilon: 0.1000 - Steps 3915 - infos : ({'lives': 1, 'episode_frame_number': 956, 'frame_number': 27276}, {'lives': 1, 'episode_frame_number': 960, 'frame_number': 26954}, {'lives': 2, 'episode_frame_number': 960, 'frame_number': 27512}, {'lives': 1, 'episode_frame_number': 932, 'frame_number': 27040})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3916 - infos : ({'lives': 1, 'episode_frame_number': 960, 'frame_number': 27280}, {'lives': 1, 'episode_frame_number': 964, 'frame_number': 26958}, {'lives': 2, 'episode_frame_number': 964, 'frame_number': 27516}, {'lives': 1, 'episode_frame_number': 936, 'frame_number': 27044})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3917 - infos : ({'lives': 1, 'episode_frame_number': 964, 'frame_number': 27284}, {'lives': 1, 'episode_frame_number': 968, 'frame_number': 26962}, {'lives': 2, 'episode_frame_number': 968, 'frame_number': 27520}, {'lives': 1, 'episode_frame_number': 940, 'frame_number': 27048})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3918 - infos : ({'lives': 1, 'episode_frame_number': 968, 'frame_number': 27288}, {'lives': 1, 'episode_frame_number': 972, 'frame_number': 26966}, {'lives': 2, 'episode_frame_number': 972, 'frame_number': 27524}, {'lives': 1, 'episode_frame_number': 944, 'frame_number': 27052})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3919 - infos : ({'lives': 1, 'episode_frame_number': 972, 'frame_number': 27292}, {'lives': 1, 'episode_frame_number': 976, 'frame_number': 26970}, {'lives': 2, 'episode_frame_number': 976, 'frame_number': 27528}, {'lives': 1, 'episode_frame_number': 948, 'frame_number': 27056})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3920 - infos : ({'lives': 1, 'episode_frame_number': 976, 'frame_number': 27296}, {'lives': 1, 'episode_frame_number': 980, 'frame_number': 26974}, {'lives': 2, 'episode_frame_number': 980, 'frame_number': 27532}, {'lives': 1, 'episode_frame_number': 952, 'frame_number': 27060})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3921 - infos : ({'lives': 1, 'episode_frame_number': 980, 'frame_number': 27300}, {'lives': 1, 'episode_frame_number': 984, 'frame_number': 26978}, {'lives': 2, 'episode_frame_number': 984, 'frame_number': 27536}, {'lives': 1, 'episode_frame_number': 956, 'frame_number': 27064})
# Episode 27 - Avg Reward: 7.00 - Epsilon: 0.1000 - Steps 3922 - infos : ({'lives': 1, 'episode_frame_number': 984, 'frame_number': 27304}, {'lives': 1, 'episode_frame_number': 988, 'frame_number': 26982}, {'lives': 2, 'episode_frame_number': 988, 'frame_number': 27540}, {'lives': 1, 'episode_frame_number': 960, 'frame_number': 27068})
# Episode 27 - Avg Reward: 7.25 - Epsilon: 0.1000 - Steps 3923 - infos : ({'lives': 1, 'episode_frame_number': 988, 'frame_number': 27308}, {'lives': 1, 'episode_frame_number': 992, 'frame_number': 26986}, {'lives': 2, 'episode_frame_number': 992, 'frame_number': 27544}, {'lives': 1, 'episode_frame_number': 964, 'frame_number': 27072})
# Episode 27 - Avg Reward: 7.25 - Epsilon: 0.1000 - Steps 3924 - infos : ({'lives': 1, 'episode_frame_number': 992, 'frame_number': 27312}, {'lives': 1, 'episode_frame_number': 996, 'frame_number': 26990}, {'lives': 2, 'episode_frame_number': 996, 'frame_number': 27548}, {'lives': 1, 'episode_frame_number': 968, 'frame_number': 27076})
# Episode 27 - Avg Reward: 7.25 - Epsilon: 0.1000 - Steps 3925 - infos : ({'lives': 1, 'episode_frame_number': 996, 'frame_number': 27316}, {'lives': 1, 'episode_frame_number': 1000, 'frame_number': 26994}, {'lives': 2, 'episode_frame_number': 1000, 'frame_number': 27552}, {'lives': 1, 'episode_frame_number': 972, 'frame_number': 27080})
# Episode 27 - Avg Reward: 7.25 - Epsilon: 0.1000 - Steps 3926 - infos : ({'lives': 1, 'episode_frame_number': 1000, 'frame_number': 27320}, {'lives': 1, 'episode_frame_number': 1004, 'frame_number': 26998}, {'lives': 2, 'episode_frame_number': 1004, 'frame_number': 27556}, {'lives': 1, 'episode_frame_number': 976, 'frame_number': 27084})
# Episode 27 - Avg Reward: 7.50 - Epsilon: 0.1000 - Steps 3927 - infos : ({'lives': 1, 'episode_frame_number': 1004, 'frame_number': 27324}, {'lives': 1, 'episode_frame_number': 1008, 'frame_number': 27002}, {'lives': 2, 'episode_frame_number': 1008, 'frame_number': 27560}, {'lives': 0, 'episode_frame_number': 980, 'frame_number': 27088})
# Episode 27 - Avg Reward: 7.75 - Epsilon: 0.1000 - Steps 3928 - infos : ({'lives': 1, 'episode_frame_number': 1008, 'frame_number': 27328}, {'lives': 1, 'episode_frame_number': 1012, 'frame_number': 27006}, {'lives': 2, 'episode_frame_number': 1012, 'frame_number': 27564}, {'lives': 0, 'episode_frame_number': 984, 'frame_number': 27092})
